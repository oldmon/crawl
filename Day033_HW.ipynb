# %% [markdown]
# # 反爬：登入授權模擬
#
# * 了解「登入權限機制」的反爬蟲機制
# * 「登入權限機制」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 找一個需要登入的網站試試看，並說明思考流程
# （如果不知道要用哪個網站的話，可以試試看 https://github.com/new 網址，未登入時會被導向登入頁）

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('https://www.sync.cloudbox.hinet.net')
soup = BeautifulSoup(res.text, 'html.parser')
print(soup.text.rstrip())
# Out:
# hicloud Box(e)         Sign In
#
#
#
#
#     body{display:none !important;}
#
#
#     if (self === top) {
#         var antiClickjack = document.getElementById("antiClickjack");
#         antiClickjack.parentNode.removeChild(antiClickjack);
#     } else {
#         top.location = self.location;
#     }
#
#
#
#
#
#
#
#
#
#
#
#
#                 submitForm = function(id) {
#                         $('loginform').submit();
#                 };
#
#         Sign In
#
#
#
#
#
#
#
#
#
#                                         Login:
#
#
#
#
#
#
#
#
#
#
#
#                                         Password:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                         Forgot your password?
#
#
#
#                                         Apply for an account
#
#
#
#
#
#
#
#                                         Remember me
#
#
#
#
#
#                 Sign in
#
#
#
# 				Copyright © 2020 Chunghwa Telecom Co., Ltd. All rights reserved.

# %% [markdown]
# Try cookie with session login auth

# %%
res = requests.get('https://www.sync.cloudbox.hinet.net',cookies={'auth':'Mzrf4DMlqByhES3-5NVA7WGm_OB-xdbIfg7FLt1Aj5I-Jjovv8dLbApABca20Qt6drZrIz8DWyfEIxaIr2ylQoycKTpehdvwOm9zZHA6b2xkbW9uQGxpdmVtYWlsLnR3OmV4cGlyZXMhMTU4NTg0NTI5OCFyZWZyZXNoVW50aWwhMTU4NzA0MDQ5Ng'})
soup = BeautifulSoup(res.text,'html.parser')
print(soup.text)
# Out:
# hicloud Box(e)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             function loadHumyo(){
#
#                 startHumyo();
#                 toolBarDisable('Up');                 getSID(); window.focus();
#
#                 new Tips('#toolbar li.tip', {position:'bottom', offset:{top:10}});
#                 new Tips('#info_left .info_header[title]', {position:'right'});
#             }
#
# 			function ignoreBrowserSupport(){
# 				refreshDir();
# 				document.fire('humyo:started');
# 			}
#
# /** This is * for GSG **/
#
#             function gsgUpload() {
#                 new WizardTip("tb_upload", {
#                     position: "bottom",
#                     loadShown: true,
#                     alwaysShown: true,
#                     closeButton: true,
#                     destroy: true,
#                     classExtra: "text-align-left",
# ...
