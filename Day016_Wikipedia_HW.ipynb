# %% [markdown]
# # Wikipedia爬蟲練習
# ## 範例：練習是從Wikipedia中爬取文章。先定義一個搜尋的關鍵字，擷取該關鍵字詞的文章。

# %%
import requests
import re
from bs4 import BeautifulSoup

# %% [markdown]
# ### 先定義一個我們想搜尋的字詞，並將它轉換成UTF-8編碼後的URL

# %%
input_keyword = "聖結石"  # 這裡可以自己定義有興趣的關鍵字

utf8_url = repr(input_keyword.encode('UTF-8')).upper()  # 編碼成UTF-8並轉成大寫字元
utf8_url = utf8_url.replace("\\X", "%")                 # 用 '%' 取代 '\X' 
print("%s: %s" % (input_keyword, utf8_url[2:-1:1]))     # 擷取中間的編碼結果

# 組成Wiki關鍵字搜尋的網址格式
root_keyword_link = '/wiki/' + utf8_url[2:-1:1]
print(root_keyword_link)
# Out:
# 聖結石: %E8%81%96%E7%B5%90%E7%9F%B3
# /wiki/%E8%81%96%E7%B5%90%E7%9F%B3

# %% [markdown]
# ### 範例1：送出關鍵字請求後，爬取該關鍵字的文章內容

# %%
# 模擬封包的標頭
headers = {
    'authority': 'zh.wikipedia.org',
    'method': 'GET',
    'path': '/wiki/' + root_keyword_link,
    'scheme': 'https',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
    'cookie': 'GeoIP=TW:TPE:Taipei:25.05:121.53:v4; TBLkisOn=0; mwPhp7Seed=8b8; WMF-Last-Access-Global=04-Jun-2019; WMF-Last-Access=04-Jun-2019',
    'dnt': '1',
    #'if-modified-since': 'Tue, 04 Jun 2019 12:03:22 GMT',
    'referer': 'https://zh.wikipedia.org/wiki/Wikipedia:%E9%A6%96%E9%A1%B5',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'
}    

url = 'https://zh.wikipedia.org' + root_keyword_link  # 組合關鍵字查詢URL
resp = requests.get(url, headers=headers)
resp.encoding = 'utf-8'

html = BeautifulSoup(resp.text, "lxml")
content = html.find(name='div', attrs={'id':'mw-content-text'}).find_all(name='p')

#
# 解析回傳資料，並萃取文章內容
#
for paragraph in content:
    print(paragraph.get_text())
# Out:
# 聖結石（英語：Saint，1990年11月13日－），本名曾聖傑，為一位網路紅人、YouTuber，過去曾為頑Game成員，而後單飛並獨自經營YouTube頻道後吸引大量粉絲訂閱，稱之為「聖粉」。聖結石是目前台灣最快突破一百萬訂閱的YouTuber（225天）。

# %% [markdown]
# ### 範例2：從爬取的文章內容中，擷取出有外部連結的關鍵字。這些關鍵字在文章中是以藍色字體顯示，會連到外部的網頁，並解釋其內容。

# %%
for ext_link in content:
    a_tag = ext_link.find_all('a', href=re.compile("^(/wiki/)((?!;)\S)*$"))
    if len(a_tag) > 0:
        for link_string in a_tag:
            a_link = link_string["href"]       # 外部連結的網址
            a_keyword = link_string.get_text()  # 外部連結的中文名稱
            print("外部連結: [%s] %s" % (a_keyword, a_link))
# Out:
# 外部連結: [網路紅人] /wiki/%E7%B6%B2%E7%B5%A1%E7%B4%85%E4%BA%BA
# 外部連結: [YouTuber] /wiki/YouTuber
# 外部連結: [台灣] /wiki/%E5%8F%B0%E7%81%A3

# %% [markdown]
# ## 作業：接下來定義一個爬蟲函數，這個函數的主要工作為：
# ### (1) 爬取當前關鍵字的解釋，並存入檔案(因為文章內容太多會佔滿整個頁面，所以存程檔案，方便後續檢視)
# ### (2) 萃取出當前關鍵字所引用的外部連結，當作新的查詢關鍵字
# ### (3) 把第(2)擷取到的關鍵字當作新的關鍵字，回到第(1)步，爬取新的關鍵字解釋。

# %%
import os.path
def WikiArticle(key_word_link, key_word, recursive):
    
    if (recursive <= max_recursive_depth):
        print("遞迴層[%d] - %s (%s)" % (recursive, key_word_link, key_word))
        
        # 模擬封包的標頭
        headers = {
            'authority': 'zh.wikipedia.org',
            'method': 'GET',
            'path': '/wiki/' + key_word_link,
            'scheme': 'https',
            'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
            'accept-encoding': 'gzip, deflate, br',
            'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
            'cookie': 'GeoIP=TW:TPE:Taipei:25.05:121.53:v4; TBLkisOn=0; mwPhp7Seed=8b8; WMF-Last-Access-Global=04-Jun-2019; WMF-Last-Access=04-Jun-2019',
            'dnt': '1',
            #'if-modified-since': 'Tue, 04 Jun 2019 12:03:22 GMT',
            'referer': 'https://zh.wikipedia.org/wiki/Wikipedia:%E9%A6%96%E9%A1%B5',
            'upgrade-insecure-requests': '1',
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'
        }    

        url = 'https://zh.wikipedia.org' + key_word_link  # 組合關鍵字查詢URL
        resp = requests.get(url, headers=headers)
        resp.encoding = 'utf-8'

        html = BeautifulSoup(resp.text, "lxml")
        content = html.find(name='div', attrs={'id':'mw-content-text'}).find_all(name='p')
        
        #
        # Part 1: 請參考範例1，爬取當前關鍵字的文章內容。
        #         因為內容太多，我們把它寫入檔案，並以關鍵字作為檔案名稱，以便稍後查閱內容。
        #         請先建立一個名為"WikiArticle"的資料夾，爬取到的文章內容會放在這個資料夾底下。
        #
        save_path='./WikiArticle/'
        if not os.path.exists(save_path):
            os.makedirs(save_path)
        completeName=os.path.join(save_path, key_word+".txt")
        file1 = open(completeName, "w")
        toWrite=''
        for paragraph in content:
            try:
                file1.write(toWrite)
            except UnicodeEncodeError:
                print(paragraph)
        file1.close()

        
        #
        # Part 2: 請參考範例2，萃取出本篇文章中所延伸引用的外部連結，並儲存在external_link_dict
        #
        external_link_dict = dict({})
        for ext_link in content:
            a_tag = ext_link.find_all('a', href=re.compile("^(/wiki/)((?!;)\S)*$"))
            if len(a_tag) > 0:
                for link_string in a_tag:
                    external_link_dict[link_string["href"]]=link_string.get_text()

                    
        #
        # Part 3: 將Part 2所收集的外部連結，當作新的關鍵字，繼續迭代深入爬蟲
        #
        if (len(external_link_dict) > 0):
            recursive += 1  # 遞迴深度加1
            for k, v in external_link_dict.items():
                WikiArticle(k, v, recursive)  # 再次呼叫同樣的函數，執行同樣的流程

# %% [markdown]
# ### 執行前個步驟定義好的爬蟲主程式

# %%
# 定義爬取的遞迴深度。深度不要訂太深，否則會爬很久。
max_recursive_depth = 2

WikiArticle(root_keyword_link, input_keyword, 0)
# Out:
# 遞迴層[0] - /wiki/%E8%81%96%E7%B5%90%E7%9F%B3 (聖結石)
# 遞迴層[1] - /wiki/%E7%B6%B2%E7%B5%A1%E7%B4%85%E4%BA%BA (網路紅人)
# 遞迴層[2] - /wiki/%E7%B6%B2%E9%9A%9B%E7%B6%B2%E8%B7%AF (網路)
# 遞迴層[2] - /wiki/%E7%A4%BE%E7%BE%A4%E7%B6%B2%E7%AB%99 (社群網站)
# 遞迴層[2] - /wiki/%E5%BD%B1%E9%9F%B3%E7%B6%B2%E7%AB%99 (影音網站)
# 遞迴層[2] - /wiki/%E8%99%9B%E6%93%AC%E7%A4%BE%E7%BE%A4 (虛擬社群)
# 遞迴層[2] - /wiki/%E7%B6%B2%E8%B7%AF%E7%88%86%E7%B4%85 (網路爆紅)
# 遞迴層[2] - /wiki/%E7%B6%B2%E8%AA%8C (部落格)
# 遞迴層[2] - /wiki/%E5%80%8B%E6%80%A7 (個性)
# 遞迴層[2] - /wiki/%E7%B2%89%E7%B5%B2 (粉絲)
# 遞迴層[2] - /wiki/%E5%B7%A5%E4%BD%9C%E5%AE%A4 (工作室)
# 遞迴層[2] - /wiki/%E7%B6%93%E7%B4%80%E5%85%AC%E5%8F%B8 (經紀公司)
# 遞迴層[2] - /wiki/%E5%93%81%E7%89%8C (品牌)
# 遞迴層[2] - /wiki/%E7%94%A2%E5%93%81 (產品)
# 遞迴層[2] - /wiki/%E5%A8%9B%E6%A8%82%E5%9C%88 (娛樂圈)
# 遞迴層[2] - /wiki/%E8%97%9D%E4%BA%BA (藝人)
# 遞迴層[2] - /wiki/%E7%B4%A0%E4%BA%BA (素人)
# 遞迴層[2] - /wiki/%E7%82%92%E4%BD%9C (炒作)
# 遞迴層[2] - /wiki/%E6%A5%AD%E9%85%8D (業配)
# 遞迴層[2] - /wiki/%E5%96%AE%E9%A0%81%E9%BB%9E%E9%96%B1%E7%8E%87 (點閱率)
# 遞迴層[2] - /wiki/%E9%BB%9E%E6%93%8A%E7%8E%87 (點擊率)
# 遞迴層[2] - /wiki/%E8%B4%8A%E5%8A%A9 (贊助)
# 遞迴層[2] - /wiki/%E7%B2%89%E7%B5%B2%E5%B0%88%E9%A0%81 (粉絲專頁)
# 遞迴層[2] - /wiki/%E6%96%87%E5%AD%97%E9%83%A8%E8%90%BD%E5%AE%A2 (文字部落客)
# 遞迴層[2] - /wiki/%E5%BD%B1%E5%83%8F%E9%83%A8%E8%90%BD%E5%AE%A2 (影像部落客)
# 遞迴層[2] - /wiki/UP%E4%B8%BB (UP主)
# 遞迴層[2] - /wiki/%E7%9B%B4%E6%92%AD%E4%B8%BB (直播主)
# 遞迴層[2] - /wiki/KOL (KOL)
# 遞迴層[2] - /wiki/YouTuber (YouTuber)
# 遞迴層[2] - /wiki/PewDiePie (PewDiePie)
# 遞迴層[1] - /wiki/YouTuber (YouTuber)
# 遞迴層[2] - /wiki/%E7%B6%B2%E7%B5%A1%E7%B4%85%E4%BA%BA (網路紅人)
# 遞迴層[2] - /wiki/YouTube (YouTube)
# 遞迴層[2] - /wiki/%E7%A4%BE%E7%BE%A4%E5%AA%92%E9%AB%94 (社群媒體)
# 遞迴層[2] - /wiki/%E5%BD%B1%E7%89%87 (影片)
# 遞迴層[2] - /wiki/%E8%8B%B1%E8%AA%9E (英語)
# 遞迴層[2] - /wiki/%E8%A9%9E%E5%B0%BE (詞尾)
# 遞迴層[2] - /wiki/%E8%81%B7%E6%A5%AD (職業)
# 遞迴層[2] - /wiki/%E8%A7%86%E9%A2%91 (影片)
# 遞迴層[2] - /wiki/%E5%B9%B3%E5%8F%B0 (平台)
# 遞迴層[2] - /wiki/Google (Google)
# 遞迴層[2] - /wiki/AdSense (AdSense)
# 遞迴層[2] - /wiki/%E5%BB%A3%E5%91%8A (廣告)
# 遞迴層[2] - /wiki/%E4%BC%81%E6%A5%AD (企業)
# 遞迴層[2] - /wiki/%E6%A5%AD%E9%85%8D (業配)
# 遞迴層[2] - /wiki/%E9%A0%BB%E9%81%93 (頻道)
# 遞迴層[2] - /wiki/%E6%97%A5%E6%9C%AC (日本)
# 遞迴層[2] - /wiki/HIKAKIN (HIKAKIN)
# 遞迴層[2] - /wiki/%E7%B6%93%E7%B4%80%E5%85%AC%E5%8F%B8 (經紀公司)
# 遞迴層[1] - /wiki/%E5%8F%B0%E7%81%A3 (台灣)
# 遞迴層[2] - /wiki/%E6%9D%B1%E4%BA%9E (東亞)
# 遞迴層[2] - /wiki/%E5%A4%AA%E5%B9%B3%E6%B4%8B (太平洋)
# 遞迴層[2] - /wiki/%E5%B3%B6%E5%B6%BC (島嶼)
# 遞迴層[2] - /wiki/%E7%90%89%E7%90%83%E7%BE%A4%E5%B3%B6 (琉球群島)
# 遞迴層[2] - /wiki/%E8%8F%B2%E5%BE%8B%E8%B3%93%E7%BE%A4%E5%B3%B6 (菲律賓群島)
# 遞迴層[2] - /wiki/%E8%87%BA%E7%81%A3%E6%B5%B7%E5%B3%BD (臺灣海峽)
# 遞迴層[2] - /wiki/%E4%B8%AD%E5%9B%BD%E5%A4%A7%E9%99%86 (中國大陸)
# 遞迴層[2] - /wiki/%E8%8F%B2%E5%BE%8B%E8%B3%93%E6%B5%B7 (菲律賓海)
# 遞迴層[2] - /wiki/%E5%B7%B4%E5%A3%AB%E6%B5%B7%E5%B3%BD (巴士海峽)
# 遞迴層[2] - /wiki/%E5%8D%97%E6%B5%B7 (南海)
# 遞迴層[2] - /wiki/%E6%9D%B1%E6%B5%B7 (東海)
# 遞迴層[2] - /wiki/%E6%9D%B1%E4%BA%9E%E5%B3%B6%E5%BC%A7 (東亞島弧)

# 遞迴層[2] - /wiki/%E4%B8%AD%E5%9C%8B%E7%B5%B1%E4%B8%80 (尚未統一的領土)
# 遞迴層[2] - /wiki/%E5%8F%B0%E7%81%A3%E7%8D%A8%E7%AB%8B%E9%81%8B%E5%8B%95 (獨)
# 遞迴層[2] - /wiki/%E5%85%AC%E6%B0%91%E7%A4%BE%E6%9C%83 (公民社會)
# 遞迴層[2] - /wiki/%E4%B8%AD%E5%9C%8B%E5%8F%B2%E8%A7%80 (中國史觀)
# 遞迴層[2] - /wiki/%E8%87%BA%E7%81%A3%E4%B8%BB%E9%AB%94%E6%80%A7 (臺灣主體意識)
# 遞迴層[2] - /wiki/%E5%A4%9A%E5%85%83%E6%96%87%E5%8C%96%E4%B8%BB%E7%BE%A9 (多元文化主義)
# 遞迴層[2] - /wiki/%E8%87%BA%E7%81%A3%E6%96%87%E5%8C%96 (臺灣文化)
# 遞迴層[2] - /wiki/%E8%A5%BF%E6%8B%89%E9%9B%85%E6%97%8F (西拉雅族)
# 遞迴層[2] - /wiki/%E5%AE%89%E5%B9%B3%E5%8D%80 (安平)
# 遞迴層[2] - /wiki/%E5%A4%A7%E6%AD%A6%E5%A3%A0%E6%97%8F (大武壠族)
# 遞迴層[2] - /wiki/%E9%96%A9%E5%8D%97%E8%AA%9E (閩南語)
# 遞迴層[2] - /wiki/%E8%87%BA%E7%81%A3%E8%8D%B7%E8%98%AD%E7%B5%B1%E6%B2%BB%E6%99%82%E6%9C%9F (臺灣荷蘭統治時期)
# 遞迴層[2] - /wiki/%E6%9D%B1%E9%83%BD (東都)
# 遞迴層[2] - /wiki/%E9%84%AD%E6%88%90%E5%8A%9F (鄭成功)
# 遞迴層[2] - /wiki/%E6%9D%B1%E5%AF%A7_(%E8%87%BA%E7%81%A3%E5%8F%A4%E5%90%8D) (東寧)
# 遞迴層[2] - /wiki/%E9%84%AD%E7%B6%93 (鄭經)
# 遞迴層[2] - /wiki/%E5%A4%A7%E6%B8%85 (大清)
# 遞迴層[2] - /wiki/%E8%87%BA%E7%81%A3%E5%BA%9C (臺灣府)
# 遞迴層[2] - /wiki/%E7%A6%8F%E7%88%BE%E6%91%A9%E6%B2%99 (福爾摩沙)
# 遞迴層[2] - /wiki/%E9%AB%98%E7%A0%82 (高砂國)
# 遞迴層[2] - /wiki/%E8%91%A1%E8%90%84%E7%89%99%E8%AA%9E (葡萄牙語)
# 遞迴層[2] - /wiki/%E8%91%A1%E8%90%84%E7%89%99 (葡萄牙)
# 遞迴層[2] - /wiki/%E5%B1%B1%E6%B5%B7%E7%B6%93 (山海經)
# 遞迴層[2] - /wiki/%E8%93%AC%E8%90%8A (蓬萊)
# 遞迴層[2] - /wiki/%E7%80%9B%E6%B4%B2 (瀛洲)
# 遞迴層[2] - /wiki/%E5%9C%B0%E5%BD%A2 (地形)
# 遞迴層[2] - /wiki/%E9%AF%A4%E5%B3%B6 (鯤島)
# 遞迴層[2] - /wiki/%E5%8D%AB%E6%B8%A9 (衛溫)
# 遞迴層[2] - /wiki/%E8%AB%B8%E8%91%9B%E7%9B%B4 (諸葛直)
# 遞迴層[2] - /wiki/%E5%AD%AB%E5%90%B3 (孫吳)
# 遞迴層[2] - /wiki/%E5%A4%B7%E6%B4%B2 (夷洲)
# 遞迴層[2] - /wiki/%E6%97%A5%E6%9C%A
# 遞迴層[2] - /wiki/%E9%A6%AC%E4%BE%86-%E7%8E%BB%E9%87%8C%E5%B0%BC%E8%A5%BF%E4%BA%9E%E8%AA%9E%E6%97%8F (馬來-玻里尼西亞語族)
# 遞迴層[2] - /wiki/%E7%B4%8B%E8%BA%AB (紋身)
# 遞迴層[2] - /wiki/%E5%8F%A3%E7%90%B4 (口琴)
# 遞迴層[2] - /wiki/%E4%BA%B2%E5%AD%90%E8%BF%9E%E5%90%8D%E5%88%B6 (親子連名制)
# 遞迴層[2] - /wiki/%E8%80%81%E4%BA%BA%E6%94%BF%E6%B2%BB (老人政治)
# 遞迴層[2] - /wiki/%E7%8C%8E%E9%A6%96 (獵首)
# 遞迴層[2] - /wiki/%E5%8D%B0%E5%BA%A6%E5%B0%BC%E8%A5%BF%E4%BA%9E (印度尼西亞)
# 遞迴層[2] - /wiki/%E4%B8%89%E5%9C%8B%E5%BF%97 (三國志)
# 遞迴層[2] - /wiki/%E4%B8%89%E5%9C%8B (三國)
# 遞迴層[2] - /wiki/%E9%9A%8B%E6%9B%B8 (隋書)
# 遞迴層[2] - /wiki/%E9%9A%8B%E7%85%AC%E5%B8%9D (隋煬帝)
# 遞迴層[2] - /wiki/%E6%B5%81%E6%B1%82%E5%9C%8B (流求國)
# 遞迴層[2] - /wiki/%E5%AE%8B%E6%9C%9D (宋朝)
# 遞迴層[2] - /wiki/%E6%BE%8E%E6%B9%96%E7%BE%A4%E5%B3%B6 (澎湖群島)
# 遞迴層[2] - /wiki/%E5%AE%8B%E5%AD%9D%E5%AE%97 (宋孝宗)
# 遞迴層[2] - /wiki/%E5%8D%97%E5%AE%8B (南宋)
# 遞迴層[2] - /wiki/%E5%AE%8B%E6%9C%9D%E8%A1%8C%E6%94%BF%E5%8D%80%E5%8A%83 (福建路)
# 遞迴層[2] - /wiki/%E6%99%89%E6%B1%9F%E7%B8%A3 (晉江縣)
# 遞迴層[2] - /wiki/%E8%B6%99%E6%B1%9D%E9%81%A9 (趙汝適)
# 遞迴層[2] - /wiki/%E8%AB%B8%E8%95%83%E5%BF%97 (諸蕃志)
# 遞迴層[2] - /wiki/%E6%BE%8E%E6%B9%96 (澎湖)
# 遞迴層[2] - /wiki/%E6%BC%81%E6%B0%91 (漁民)
# 遞迴層[2] - /wiki/%E5%85%83%E4%B8%96%E7%A5%96 (元世祖)
# 遞迴層[2] - /wiki/%E5%85%83%E6%97%A5%E6%88%B0%E7%88%AD (元軍東征日本)
# 遞迴層[2] - /wiki/%E9%A2%B1%E9%A2%A8 (颱風)
# 遞迴層[2] - /wiki/%E6%BE%8E%E6%B9%96%E5%B7%A1%E6%AA%A2%E5%8F%B8 (澎湖巡檢司)
# 遞迴層[2] - /wiki/%E7%A6%8F%E5%BB%BA (福建)
# 遞迴層[2] - /wiki/%E6%B3%89%E5%B7%9E%E8%B7%AF (泉州路)
# 遞迴層[2] - /wiki/%E6%BE%8E%E6%B9%96%E5%AF%A8%E5%B7%A1%E6%AA%A2 (澎湖寨巡檢)
# 遞迴層[2] - /wiki/%E6%98%8E%E6%9C%9D (明朝)
# 遞迴層[2] - /wiki/%E6%98%8E%E5%A4%AA%E7%A5%96 (明太祖)
# 遞迴層[2] - /wiki/%E7%9A%87%E6%98%8E%E7%A5%96%E8%A8%93 (皇明祖訓)
# 遞迴層[2] - /wiki/%E4%B8%8D%E5%BE%81%E4%B9%8B%E5%9C%8B (不征之國)
# 遞迴層[2] - /wiki/%E7%90%89%E7%90%83%E5%9C%8B (琉球國)
# 遞迴層[2] - /wiki/%E5%B0%8F%E7%90%89%E7%90%83 (小琉球)
# 遞迴層[2] - /wiki/%E6%98%8E%E4%B8%96%E5%AE%97 (明世宗)
# 遞迴層[2] - /wiki/%E5%98%89%E9%9D%96 (嘉靖)
# 遞迴層[2] - /wiki/%E8%8D%B7%E8%98%AD%E6%9D%B1%E5%8D%B0%E5%BA%A6%E5%85%AC%E5%8F%B8 (荷蘭東印度公司)
# 遞迴層[2] - /wiki/%E7%A6%8F%E5%BB%BA%E5%B7%A1%E6%92%AB (福建省巡撫)
# 遞迴層[2] - /wiki/%E5%8D%97%E5%B1%85%E7%9B%8A (南居益)
# 遞迴層[2] - /wiki/%E6%BE%8E%E6%B9%96%E4%B9%8B%E6%88%98 (澎湖之戰)
# 遞迴層[2] - /wiki/%E8%8D%B7%E8%98%AD%E5%85%B1%E5%92%8C%E5%9C%8B (荷蘭共和國)
# 遞迴層[2] - /wiki/%E5%80%AD%E5%AF%87_(%E6%B5%B7%E7%9B%9C) (倭寇)
# 遞迴層[2] - /wiki/%E6%B5%B7%E7%9B%9C (海盜)
# 遞迴層[2] - /wiki/%E4%B8%AD%E5%9C%8B (中國)
# 遞迴層[2] - /wiki/%E8%91%A1%E8%90%84%E7%89%99%E5%B8%9D%E5%9C%8B (葡萄牙人)
# 遞迴層[2] - /wiki/%E4%B8%9C%E4%BA%9A (東亞)
# 遞迴層[2] - /wiki/%E8%87%BA%E7%81%A3%E8%8D%B7%E8%A5%BF%E6%AE%96%E6%B0%91%E6%99%82%E6%9C%9F (殖民臺灣)
# 遞迴層[2] - /wiki/%E9%B4%89%E7%89%87 (鴉片)
# 遞迴層[2] - /wiki/%E7%A8%BB%E7%B1%B3 (稻米)
# 遞迴層[2] - /wiki/%E6%9D%B1%E7%95%AA (東番)
# 遞迴層[2] - /wiki/%E8%B5%A4%E5%B4%81 (赤崁)
# 遞迴層[2] - /wiki/%E9%A1%8F%E6%80%9D%E9%BD%8A (顏思齊)
# 遞迴層[2] - /wiki/%E7%AC%A8%E6%B8%AF (笨港)
# 遞迴層[2] - /wiki/%E9%9B%B2%E6%9E%97%E7%B8%A3 (雲林縣)
# 遞迴層[2] - /wiki/%E5%8C%97%E6%B8%AF%E9%8E%AE_(%E8%87%BA%E7%81%A3) (北港)
# 遞迴層[2] - /wiki/%E5%98%89%E7%BE%A9%E7%B8%A3 (嘉義)
# 遞迴層[2] - /wiki/%E6%96%B0%E6%B8%AF%E9%84%89 (新港)
# 遞迴層[2] - /wiki/%E9%84%AD%E8%8A%9D%E9%BE%8D (鄭芝龍)
# 遞迴層[2] - /wiki/%E9%96%A9%E5%8D%97 (閩南)
# 遞迴層[2] - /wiki/%E4%B8%AD%E8%87%BA%E7%81%A3 (中臺灣)
# 遞迴層[2] - /wiki/%E5%B7%B4%E5%B8%83%E6%8B%89%E6%97%8F (巴布拉族)
# 遞迴層[2] - /wiki/%E8%B2%93%E9%9C%A7%E6%8D%92%E6%97%8F (貓霧捒族)
# 遞迴層[2] - /wiki/%E5%B7%B4%E5%89%87%E6%B5%B7%E6%97%8F (巴則海族)
# 遞迴層[2] - /wiki/%E6%B4%AA%E9%9B%85%E6%97%8F (洪雅族)
# 遞迴層[2] - /wiki/%E9%81%93%E5%8D%A1%E6%96%AF%E6%97%8F (道卡斯族)
# 遞迴層[2] - /wiki/%E7%A4%BE (社)
# 遞迴層[2] - /wiki/%E9%B9%BF%E6%B8%AF%E9%8E%AE (鹿港)
# 遞迴層[2] - /wiki/%E6%A1%83%E5%9C%92%E5%B8%82 (桃園市)
# 遞迴層[2] - /wiki/%E5%A4%A7%E8%82%9A%E6%BA%AA (大肚溪)
# 遞迴層[2] - /wiki/%E8%8D%B7%E8%98%AD%E4%BA%BA (荷蘭人)
# 遞迴層[2] - /wiki/%E8%8D%B7%E5%85%B0%E4%B8%9C%E5%8D%B0%E5%BA%A6%E5%85%AC%E5%8F%B8 (荷蘭東印度公司)
# 遞迴層[2] - /wiki/%E6%98%8E%E9%84%AD (明鄭)
# 遞迴層[2] - /wiki/%E5%85%B5%E5%86%9C%E5%90%88%E4%B8%80 (兵農合一)
# 遞迴層[2] - /wiki/%E6%B8%85%E6%9C%9D (大清帝國)
# 遞迴層[2] - /wiki/%E5%BA%B7%E7%86%99 (康熙)
# 遞迴層[2] - /wiki/%E5%B7%A1%E5%8F%B0%E5%BE%A1%E5%8F%B2 (巡臺御史)
# 遞迴層[2] - /wiki/%E9%BB%83%E5%8F%94%E7%92%A5 (黃叔璥)
# 遞迴層[2] - /wiki/%E8%87%BA%E6%B5%B7%E4%BD%BF%E6%A7%8E%E9%8C%84 (臺海使槎錄)
# 遞迴層[2] - /wiki/%E9%9B%8D%E6%AD%A3 (雍正)
# 遞迴層[2] - /wiki/%E5%A4%A7%E7%94%B2%E8%A5%BF%E7%A4%BE%E6%8A%97%E6%B8%85%E4%BA%8B%E4%BB%B6 (大甲西社抗清事件)
# 遞迴層[2] - /wiki/%E5%9F%94%E9%87%8C%E9%8E%AE (埔里)
# 遞迴層[2] - /wiki/%E5%8D%97%E6%8A%95%E7%B8%A3 (南投縣)
# 遞迴層[2] - /wiki/%E5%A4%A7%E5%93%A1 (大員)
# 遞迴層[2] - /wiki/%E4%B8%89%E8%B2%82%E8%A7%92 (三貂角)
# 遞迴層[2] - /wiki/%E8%B2%BF%E6%98%93 (貿易)
# 遞迴層[2] - /wiki/%E6%B2%88%E6%9C%89%E5%AE%B9 (沈有容)
# 遞迴層[2] - /wiki/%E5%9B%9B%E8%8D%89 (四草)
# 遞迴層[2] - /wiki/%E4%B8%80%E9%AF%A4%E9%AF%93 (一鯤鯓)
# 遞迴層[2] - /wiki/%E5%AE%89%E5%B9%B3%E5%8F%A4%E5%A0%A1 (安平古堡)
# 遞迴層[2] - /wiki/%E8%A5%BF%E7%8F%AD%E7%89%99 (西班牙)
# 遞迴層[2] - /wiki/%E8%A5%BF%E7%8F%AD%E7%89%99%E4%BA%BA (西班牙人)
# 遞迴層[2] - /wiki/%E5%9F%BA%E9%9A%86 (基隆)
# 遞迴層[2] - /wiki/%E5%92%8C%E5%B9%B3%E5%B3%B6 (和平島)
# 遞迴層[2] - /wiki/%E8%81%96%E8%96%A9%E7%88%BE%E7%93%A6%E5%A4%9A%E5%9F%8E_(%E8%87%BA%E7%81%A3) (聖薩爾瓦多城)
# 遞迴層[2] - /wiki/%E5%AE%9C%E8%98%AD%E7%B8%A3 (宜蘭)
# 遞迴層[2] - /wiki/%E6%B7%A1%E6%B0%B4%E5%8D%80 (淡水)
# 遞迴層[2] - /wiki/%E7%B4%85%E6%AF%9B%E5%9F%8E (紅毛城)
# 遞迴層[2] - /wiki/%E6%B1%9F%E6%88%B6%E5%B9%95%E5%BA%9C (江戶幕府)
# 遞迴層[2] - /wiki/%E9%94%81%E5%9B%BD_(%E6%97%A5%E6%9C%AC) (鎖國)
# 遞迴層[2] - /wiki/%E9%9B%9E%E7%B1%A0 (雞籠)
# 遞迴層[2] - /wiki/%E6%9C%9D%E9%AE%AE%E5%8D%8A%E5%B3%B6 (朝鮮半島)
# 遞迴層[2] - /wiki/%E5%8D%97%E6%B4%8B (南洋)
# 遞迴層[2] - /wiki/%E8%8D%B7%E8%98%AD%E6%9D%B1%E5%8D%B0%E5%BA%A6%E5%85%AC%E5%8F%B8#與臺灣的貿易關係 (荷蘭東印度公司)
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-6-5bcc6df82908> in <module>
#       2 max_recursive_depth = 2
#       3
# ----> 4 WikiArticle(root_keyword_link, input_keyword, 0)
#
# <ipython-input-5-ff54a20590e0> in WikiArticle(key_word_link, key_word, recursive)
#      65             recursive += 1  # 遞迴深度加1
#      66             for k, v in external_link_dict.items():
# ---> 67                 WikiArticle(k, v, recursive)  # 再次呼叫同樣的函數，執行同樣的流程
#      68
#
# <ipython-input-5-ff54a20590e0> in WikiArticle(key_word_link, key_word, recursive)
#      65             recursive += 1  # 遞迴深度加1
#      66             for k, v in external_link_dict.items():
# ---> 67                 WikiArticle(k, v, recursive)  # 再次呼叫同樣的函數，執行同樣的流程
#      68
#
# <ipython-input-5-ff54a20590e0> in WikiArticle(key_word_link, key_word, recursive)
#      23
#      24         url = 'https://zh.wikipedia.org' + key_word_link  # 組合關鍵字查詢URL
# ---> 25         resp = requests.get(url, headers=headers)
#      26         resp.encoding = 'utf-8'
#      27
#
# ~\.conda\envs\crawl\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\.conda\envs\crawl\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\.conda\envs\crawl\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\.conda\envs\crawl\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\.conda\envs\crawl\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~\.conda\envs\crawl\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     670                 body=body,
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#     674
#
# ~\.conda\envs\crawl\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385             conn.request_chunked(method, url, **httplib_request_kw)
#     386         else:
# --> 387             conn.request(method, url, **httplib_request_kw)
#     388
#     389         # Reset the timeout for the recv() on the socket
#
# ~\.conda\envs\crawl\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1250                 encode_chunked=False):
#    1251         """Send a complete request to the server."""
# -> 1252         self._send_request(method, url, body, headers, encode_chunked)
#    1253
#    1254     def _send_request(self, method, url, body, headers, encode_chunked):
#
# ~\.conda\envs\crawl\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1291
#    1292         for hdr, value in headers.items():
# -> 1293             self.putheader(hdr, value)
#    1294         if isinstance(body, str):
#    1295             # RFC 2616 Section 3.7.1 says that text default has a
#
# ~\.conda\envs\crawl\lib\http\client.py in putheader(self, header, *values)
#    1223         for i, one_value in enumerate(values):
#    1224             if hasattr(one_value, 'encode'):
# -> 1225                 values[i] = one_value.encode('latin-1')
#    1226             elif isinstance(one_value, int):
#    1227                 values[i] = str(one_value).encode('ascii')
#
# UnicodeEncodeError: 'latin-1' codec can't encode characters in position 76-83: ordinal not in range(256)
